# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/health_finance.csv")

# %%
df.head()
# Out:
#    patient_id  age  gender    bmi smoking_status alcohol_use  diabetes  \
# 0           1   58    Male  24.60     Non-Smoker          No         1
# 1           2   47    Male  21.86     Non-Smoker          No         0
# 2           3   61    Male  29.51     Non-Smoker         Yes         1
# 3           4   77    Male  18.47         Smoker          No         0
# 4           5   45  Female  25.66     Non-Smoker          No         0
#
#    hypertension  heart_disease  cholesterol  ...  hospital_revenue  \
# 0             0              0       301.23  ...        5636673.96
# 1             0              0       242.76  ...        4571958.99
# 2             1              1       329.49  ...        4232347.29
# 3             1              1       268.13  ...        3879418.67
# 4             0              0       300.29  ...        4579692.52
#
#    hospital_expense  hospital_credit_score  pharma_stock_return  \
# 0        3737763.70                    677                25.17
# ...

# %%
df.shape
# Out:
# (9992, 40)

# %%
df.sample(7) # 7 random samples
# Out:
#       patient_id  age  gender    bmi smoking_status alcohol_use  diabetes  \
# 9718        9719   60  Female  35.56     Non-Smoker          No         1
# 999         1000   60    Male  40.36     Non-Smoker          No         1
# 7264        7265   47    Male  24.25     Non-Smoker          No         0
# 3896        3897   75  Female  32.00     Non-Smoker         Yes         1
# 9597        9598   49  Female  22.53     Non-Smoker         Yes         0
# 9638        9639   39  Female  16.55     Non-Smoker          No         0
# 4719        4720   52    Male  37.67     Non-Smoker          No         0
#
#       hypertension  heart_disease  cholesterol  ...  hospital_revenue  \
# 9718             1              1       300.91  ...        4604272.65
# 999              1              1       316.64  ...        3453766.05
# 7264             0              0       273.78  ...        4082506.78
# 3896             1              1       292.80  ...        5125846.08
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9992 entries, 0 to 9991
# Data columns (total 40 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   patient_id              9992 non-null   int64
#  1   age                     9992 non-null   int64
#  2   gender                  9992 non-null   object
#  3   bmi                     9792 non-null   float64
#  4   smoking_status          9992 non-null   object
#  5   alcohol_use             9992 non-null   object
#  6   diabetes                9992 non-null   int64
#  7   hypertension            9992 non-null   int64
#  8   heart_disease           9992 non-null   int64
#  9   cholesterol             9792 non-null   float64
#  10  glucose                 9792 non-null   float64
#  11  systolic_bp             9992 non-null   float64
#  12  diastolic_bp            9992 non-null   float64
#  13  heart_rate              9992 non-null   int64
# ...

# %%
print(df.isnull().sum())
# Out:
# patient_id                  0
# age                         0
# gender                      0
# bmi                       200
# smoking_status              0
# alcohol_use                 0
# diabetes                    0
# hypertension                0
# heart_disease               0
# cholesterol               200
# glucose                   200
# systolic_bp                 0
# diastolic_bp                0
# heart_rate                  0
# oxygen_saturation           0
# hospital_visits             0
# icu_admission               0
# length_of_stay              0
# readmission                 0
# mortality_risk              0
# disease_outbreak_index      0
# treatment_type              0
# drug_name                   0
# drug_efficacy             200
# side_effect_score           0
# insurance_plan              0
# annual_premium              0
# claim_amount              200
# claim_frequency             0
# fraud_risk                  0
# hospital_revenue            0
# ...

# %%
print((df.isnull().sum()/len(df))*100)
# Out:
# patient_id                0.000000
# age                       0.000000
# gender                    0.000000
# bmi                       2.001601
# smoking_status            0.000000
# alcohol_use               0.000000
# diabetes                  0.000000
# hypertension              0.000000
# heart_disease             0.000000
# cholesterol               2.001601
# glucose                   2.001601
# systolic_bp               0.000000
# diastolic_bp              0.000000
# heart_rate                0.000000
# oxygen_saturation         0.000000
# hospital_visits           0.000000
# icu_admission             0.000000
# length_of_stay            0.000000
# readmission               0.000000
# mortality_risk            0.000000
# disease_outbreak_index    0.000000
# treatment_type            0.000000
# drug_name                 0.000000
# drug_efficacy             2.001601
# side_effect_score         0.000000
# insurance_plan            0.000000
# annual_premium            0.000000
# ...

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.describe())
# Out:
#         patient_id          age          bmi     diabetes  hypertension  \
# count  9992.000000  9992.000000  9792.000000  9992.000000   9992.000000
# mean   4996.500000    49.679043    27.306509     0.222978      0.343475
# std    2884.586279    17.200280     5.432937     0.416265      0.474892
# min       1.000000    18.000000    15.000000     0.000000      0.000000
# 25%    2498.750000    37.000000    23.640000     0.000000      0.000000
# 50%    4996.500000    49.000000    27.120000     0.000000      0.000000
# 75%    7494.250000    62.000000    30.630000     0.000000      1.000000
# max    9992.000000    90.000000    61.450000     1.000000      1.000000
#
#        heart_disease  cholesterol      glucose  systolic_bp  diastolic_bp  \
# count    9992.000000  9792.000000  9792.000000  9992.000000   9992.000000
# mean        0.240793   268.647518   119.089200   133.596220     81.697350
# std         0.427586    47.230217    29.150338    15.850755      7.711245
# ...
